# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Linda Durbin**
# Data Scientist

# %% [markdown]
# *Data Manipulation and reporting have always been a strength for me. I enjoy working and attempting to understand large sets of data. I am interested in Data Science because I would like to increase my skillset.*

# %% [markdown]
# ### The code in the next cell is going to solve a very simple math problem.

# %%
5+10
# Out:
# 15

# %% [markdown]
# > “You can have data without information, but you cannot have information without data.” — Daniel Keys Moran
# ---
#
# The 5 V's of Data
# 1. Velocity
# 2. Volume
# 3. Value
# 4. Variety
# 5. Veracity
#
# ***
#
# |Just|For|Fun|
# |---|---|---|
# |Have|A Good|Day|
